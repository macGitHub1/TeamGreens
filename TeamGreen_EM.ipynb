# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import TeamGreen_EM

# %%
TeamGreen_EM.run()

# %%
TeamGreen_EM.runState(state= "Texas", drug= "Alcohol")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b8fbcb7950c2> in <module>()
# ----> 1 TeamGreen_EM.runState(state= "Texas", drug= "Alcohol")
#
# ~/ucsd/Projects/TeamGreens/TeamGreen_EM.py in runState(state, drug)
#      27     ax.plot(sorted_state_df["Year"],sorted_state_df[drug])
#      28     outputPng = state + drug +".png"
# ---> 29     plt.savefig(outputPng)
#      30
#      31
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
data_source = pd.read_csv('Data_em.csv')
data_source.head()
# Out:
#         State  Marijuana  Alcohol  Year
# 0  Total U.S.     0.0860   0.5121  2016
# 1   Northeast     0.0950   0.5602  2016
# 2     Midwest     0.0828   0.5436  2016
# 3       South     0.0705   0.4748  2016
# 4        West     0.1068   0.5067  2016

# %%
TeamGreen_EM.runBothState("Arkansas")
# Out:
# /Users/emccoy/ucsd/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
#do CO
col_df = data_source.set_index("State")
col_df1 = col_df.loc['Colorado'].sort_values("Year",ascending=False)
wash_df1 = col_df.loc['Washington'].sort_values("Year",ascending=False)

print(col_df1.head())
fig = plt.figure()
ax = plt.axes()   
ax.plot(col_df1["Year"],col_df1["Alcohol"])
ax.plot(wash_df1["Year"],wash_df1["Alcohol"])
# Out:
#           Marijuana  Alcohol  Year
# State
# Colorado     0.1592   0.5753  2016
# Colorado     0.1657   0.5922  2015
# Colorado     0.1493   0.6156  2014
# Colorado     0.1270   0.6103  2013

# %%
TeamGreen_EM.runState(state="California", drug = "Marijuana")

# %%
TeamGreen_EM.runState(state="California", drug = "Alcohol")

# %%
fig = plt.figure()
ax = plt.axes()   
ax.plot(col_df1["Year"],col_df1["Marijuana"])

# %%
sns.lmplot(data=col_df1,
           x='Year',
           y='Alcohol',
           fit_reg=False)

# %%
#do CO
col_df = data_source.set_index("State")
col_df.head()



#multiple line plot
plt.plot( 'State', 'Alcohol', data=data_source, marker='', markerfacecolor='blue', markersize=8, color='skyblue', linewidth=2)
#plt.plot( 'x', 'y2', data=data_source, marker='', color='olive', linewidth=2)
#plt.plot( 'x', 'y3', data=data_source, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.legend()

# %%
# Show the results of a linear regression within each dataset
sns.lmplot(data=data_source,
           x='Marijuana',
           y='Alcohol',
           hue='State',
           fit_reg=False)

# %%
print (data_source.groupby(["State","Alcohol"]).groups)
# Out:
# {('Alabama', 0.4079): Int64Index([5], dtype='int64'), ('Alabama', 0.4363): Int64Index([117], dtype='int64'), ('Alabama', 0.4394): Int64Index([61], dtype='int64'), ('Alabama', 0.4472): Int64Index([173], dtype='int64'), ('Alaska', 0.5272): Int64Index([6], dtype='int64'), ('Alaska', 0.5301): Int64Index([118], dtype='int64'), ('Alaska', 0.5402): Int64Index([174], dtype='int64'), ('Alaska', 0.5498): Int64Index([62], dtype='int64'), ('Arizona', 0.5094): Int64Index([7], dtype='int64'), ('Arizona', 0.5112): Int64Index([119], dtype='int64'), ('Arizona', 0.5119): Int64Index([63], dtype='int64'), ('Arizona', 0.518): Int64Index([175], dtype='int64'), ('Arkansas', 0.4014): Int64Index([8], dtype='int64'), ('Arkansas', 0.4144): Int64Index([120], dtype='int64'), ('Arkansas', 0.4181): Int64Index([64], dtype='int64'), ('Arkansas', 0.4245): Int64Index([176], dtype='int64'), ('California', 0.4943): Int64Index([121], dtype='int64'), ('California', 0.4974): Int64Index([9], dtype='int64'), ('California', 0
# ...
