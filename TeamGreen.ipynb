# %%
#import team py files
import TeamGreen_EM
import TeamGreen_JDW
import TeamGreen_Divya
import TeamGreen_GAF

# %%
#Crime with Marijuana
TeamGreen_Divya.run()
#TeamGreen_Divya.run_total() TBD

# %%
TeamGreen_GAF.run()
TeamGreen_GAF.run2()
TeamGreen_GAF.run3()
TeamGreen_GAF.run4()
TeamGreen_GAF.run5()
TeamGreen_GAF.run6()
TeamGreen_GAF.run7()
TeamGreen_GAF.run8()
TeamGreen_GAF.run9()

# %%
TeamGreen_JDW.runOrg()
TeamGreen_JDW.runWA()
TeamGreen_JDW.runCO()

# %%
#example of calling your function in your py file
# in a cell prior to plotting you should speak on your findings
#This is plot is showing the all states with Alcohol versus Marijuana
#each axes in percent of the population
TeamGreen_EM.run()

# %%
#Data showing Colorado usage of Alcohol
TeamGreen_EM.runState(state = "Colorado", drug = "Alcohol")

# %%
#Data showing Colorado usage of Alcohol
TeamGreen_EM.runState(state = "Colorado", drug = "Marijuana")
