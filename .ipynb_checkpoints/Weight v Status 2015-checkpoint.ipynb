# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = "Resources/WT v MJSTAT-15.csv"

# %%
df = pd.read_csv(file)
df.head()
# Out:
#     STATE MEDICAL MJ LAW STATUS AT TIME OF INTERVIEW  \
# 0  1 - In State where MJ approvd for med use befo...
# 1  1 - In State where MJ approvd for med use befo...
# 2  1 - In State where MJ approvd for med use befo...
# 3  1 - In State where MJ approvd for med use befo...
# 4  1 - In State where MJ approvd for med use befo...
#
#   WEIGHT IN POUNDS - RECODE   Total %  Total % SE  Total % CI (lower)  \
# 0                       100  0.002680    0.000266            0.002197
# 1                       101  0.000402    0.000085            0.000263
# 2                       102  0.000408    0.000088            0.000264
# 3                       103  0.000797    0.000120            0.000590
# 4                       104  0.000749    0.000182            0.000461
#
#    Total % CI (upper)     Row %  Row % SE  Row % CI (lower)  Row % CI (upper)  \
# 0            0.003270  0.437357  0.038182          0.362726          0.514936
# 1            0.000614  0.300891  0.074406          0.174578          0.466899
# 2            0.000630  0.460325  0.072733          0.321455          0.605640
# 3            0.001077  0.443519  0.065005          0.319536          0.574961
# 4            0.001219  0.588690  0.076985          0.430439          0.730500
#
#    Column %  Column % SE  Column % CI (lower)  Column % CI (upper)  \
# 0  0.005697     0.000565             0.004668             0.006952
# 1  0.000854     0.000182             0.000557             0.001311
# 2  0.000866     0.000186             0.000562             0.001334
# 3  0.001694     0.000258             0.001248             0.002299
# 4  0.001593     0.000384             0.000981             0.002585
#
#    Weighted Count  Unweighted Count      Count SE
# 0   699700.662562             277.0  67874.374865
# 1   104906.735782              33.0  22026.255020
# 2   106378.571674              45.0  23070.818451
# 3   208071.093028              69.0  31109.660443
# 4   195616.356151              57.0  47617.940926

# %%
new_df = df[['STATE MEDICAL MJ LAW STATUS AT TIME OF INTERVIEW',
             'WEIGHT IN POUNDS - RECODE',
            'Unweighted Count']]
new_df.reset_index

new_df.head()
# Out:
#     STATE MEDICAL MJ LAW STATUS AT TIME OF INTERVIEW  \
# 0  1 - In State where MJ approvd for med use befo...
# 1  1 - In State where MJ approvd for med use befo...
# 2  1 - In State where MJ approvd for med use befo...
# 3  1 - In State where MJ approvd for med use befo...
# 4  1 - In State where MJ approvd for med use befo...
#
#   WEIGHT IN POUNDS - RECODE  Unweighted Count
# 0                       100             277.0
# 1                       101              33.0
# 2                       102              45.0
# 3                       103              69.0
# 4                       104              57.0

# %%
drop_df = new_df.drop(new_df.index[442:667])
drop_df.reset_index
drop_df
# Out:
#       STATE MEDICAL MJ LAW STATUS AT TIME OF INTERVIEW  \
# 0    1 - In State where MJ approvd for med use befo...
# 1    1 - In State where MJ approvd for med use befo...
# 2    1 - In State where MJ approvd for med use befo...
# 3    1 - In State where MJ approvd for med use befo...
# 4    1 - In State where MJ approvd for med use befo...
# 5    1 - In State where MJ approvd for med use befo...
# 6    1 - In State where MJ approvd for med use befo...
# 7    1 - In State where MJ approvd for med use befo...
# 8    1 - In State where MJ approvd for med use befo...
# 9    1 - In State where MJ approvd for med use befo...
# 10   1 - In State where MJ approvd for med use befo...
# 11   1 - In State where MJ approvd for med use befo...
# 12   1 - In State where MJ approvd for med use befo...
# 13   1 - In State where MJ approvd for med use befo...
# 14   1 - In State where MJ approvd for med use befo...
# 15   1 - In State where MJ approvd for med use befo...
# 16   1 - In State where MJ approvd for med use befo...
# 17   1 - In State where MJ approvd for med use befo...
# 18   1 - In State where MJ approvd for med use befo...
# 19   1 - In State where MJ approvd for med use befo...
# 20   1 - In State where MJ approvd for med use befo...
# 21   1 - In State where MJ approvd for med use befo...
# 22   1 - In State where MJ approvd for med use befo...
# 23   1 - In State where MJ approvd for med use befo...
# 24   1 - In State where MJ approvd for med use befo...
# 25   1 - In State where MJ approvd for med use befo...
# 26   1 - In State where MJ approvd for med use befo...
# 27   1 - In State where MJ approvd for med use befo...
# 28   1 - In State where MJ approvd for med use befo...
# 29   1 - In State where MJ approvd for med use befo...
# ..                                                 ...
# 412  2 - Not in State MJ approvd for med use/by int...
# 413  2 - Not in State MJ approvd for med use/by int...
# 414  2 - Not in State MJ approvd for med use/by int...
# 415  2 - Not in State MJ approvd for med use/by int...
# 416  2 - Not in State MJ approvd for med use/by int...
# 417  2 - Not in State MJ approvd for med use/by int...
# 418  2 - Not in State MJ approvd for med use/by int...
# 419  2 - Not in State MJ approvd for med use/by int...
# 420  2 - Not in State MJ approvd for med use/by int...
# 421  2 - Not in State MJ approvd for med use/by int...
# 422  2 - Not in State MJ approvd for med use/by int...
# 423  2 - Not in State MJ approvd for med use/by int...
# 424  2 - Not in State MJ approvd for med use/by int...
# 425  2 - Not in State MJ approvd for med use/by int...
# 426  2 - Not in State MJ approvd for med use/by int...
# 427  2 - Not in State MJ approvd for med use/by int...
# 428  2 - Not in State MJ approvd for med use/by int...
# 429  2 - Not in State MJ approvd for med use/by int...
# 430  2 - Not in State MJ approvd for med use/by int...
# 431  2 - Not in State MJ approvd for med use/by int...
# 432  2 - Not in State MJ approvd for med use/by int...
# 433  2 - Not in State MJ approvd for med use/by int...
# 434  2 - Not in State MJ approvd for med use/by int...
# 435  2 - Not in State MJ approvd for med use/by int...
# 436  2 - Not in State MJ approvd for med use/by int...
# 437  2 - Not in State MJ approvd for med use/by int...
# 438  2 - Not in State MJ approvd for med use/by int...
# 439  2 - Not in State MJ approvd for med use/by int...
# 440  2 - Not in State MJ approvd for med use/by int...
# 441  2 - Not in State MJ approvd for med use/by int...
#
#     WEIGHT IN POUNDS - RECODE  Unweighted Count
# 0                         100             277.0
# 1                         101              33.0
# 2                         102              45.0
# 3                         103              69.0
# 4                         104              57.0
# 5                         105             204.0
# 6                         106              55.0
# 7                         107              64.0
# 8                         108              88.0
# 9                         109              41.0
# 10                        110             465.0
# 11                        111              41.0
# 12                        112             109.0
# 13                        113              77.0
# 14                        114              63.0
# 15                        115             432.0
# 16                        116              84.0
# 17                        117             102.0
# 18                        118             152.0
# 19                        119              64.0
# 20                        120             696.0
# 21                        121              73.0
# 22                        122              61.0
# 23                        123             116.0
# 24                        124              84.0
# 25                        125             615.0
# 26                        126              93.0
# 27                        127             112.0
# 28                        128             158.0
# 29                        129              74.0
# ..                        ...               ...
# 412                       291               1.0
# 413                       292               1.0
# 414                       293               2.0
# 415                       294               3.0
# 416                       295             685.0
# 417                        75             153.0
# 418                        76               9.0
# 419                        77               9.0
# 420                        78              12.0
# 421                        79               7.0
# 422                        80              44.0
# 423                        81               7.0
# 424                        82              14.0
# 425                        83               7.0
# 426                        84              14.0
# 427                        85              53.0
# 428                        86              13.0
# 429                        87              30.0
# 430                        88              16.0
# 431                        89              17.0
# 432                        90              94.0
# 433                        91              14.0
# 434                        92              24.0
# 435                        93              31.0
# 436                        94              22.0
# 437                        95             140.0
# 438                        96              38.0
# 439                        97              60.0
# 440                        98              97.0
# 441                        99              30.0
#
# [442 rows x 3 columns]

# %%
drop_df[['WEIGHT IN POUNDS - RECODE', 'Unweighted Count']] = drop_df[['WEIGHT IN POUNDS - RECODE', 'Unweighted Count']].astype(float)
drop_df['Total Weight'] = np.multiply(drop_df['WEIGHT IN POUNDS - RECODE'], drop_df['Unweighted Count'])
drop_df.head()
# Out:
#     STATE MEDICAL MJ LAW STATUS AT TIME OF INTERVIEW  \
# 0  1 - In State where MJ approvd for med use befo...
# 1  1 - In State where MJ approvd for med use befo...
# 2  1 - In State where MJ approvd for med use befo...
# 3  1 - In State where MJ approvd for med use befo...
# 4  1 - In State where MJ approvd for med use befo...
#
#    WEIGHT IN POUNDS - RECODE  Unweighted Count  Total Weight
# 0                      100.0             277.0       27700.0
# 1                      101.0              33.0        3333.0
# 2                      102.0              45.0        4590.0
# 3                      103.0              69.0        7107.0
# 4                      104.0              57.0        5928.0

# %%
total_weight = drop_df.groupby(['STATE MEDICAL MJ LAW STATUS AT TIME OF INTERVIEW'])['Total Weight'].sum()
total_count = drop_df.groupby(['STATE MEDICAL MJ LAW STATUS AT TIME OF INTERVIEW'])['Unweighted Count'].sum()
avg_weight = total_weight/total_count
status = drop_df.groupby(['STATE MEDICAL MJ LAW STATUS AT TIME OF INTERVIEW'])
avg_weight
# Out:
# STATE MEDICAL MJ LAW STATUS AT TIME OF INTERVIEW
# 1 - In State where MJ approvd for med use before intvw    166.036958
# 2 - Not in State MJ approvd for med use/by intvw date     170.443814
# dtype: float64

# %%
final_df = pd.DataFrame({"Average Weight": avg_weight})
final_df
# Out:
#                                                     Average Weight
# STATE MEDICAL MJ LAW STATUS AT TIME OF INTERVIEW
# 1 - In State where MJ approvd for med use befor...      166.036958
# 2 - Not in State MJ approvd for med use/by intv...      170.443814

# %%
fig, ax = plt.subplots()
index = np.arange(len(avg_weight)) 
bar_width = 0.2
opacity = 0.4
error_config = {'ecolor': '0.3'}



rects1 = ax.bar(index, avg_weight, bar_width,
               alpha=opacity, color='b',
               error_kw=error_config,
               )


ax.set
ax.set_ylabel("Average Weight (Pounds)")
ax.set_title("Avg Weight of Participant v State Approval of Marijuana")
ax.set_xticks(index)
ax.set_xticklabels(('State Approves Med. Marijuana', 'State Does Not Approve Med. Marijuana'), rotation=60,ha='right')

def autolabelPass(rects1):
    for rect in rects1:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 3,
                '%.1f' % float(height),
                ha='center', va='bottom', color="white")

autolabelPass(rects1)

plt.show()
